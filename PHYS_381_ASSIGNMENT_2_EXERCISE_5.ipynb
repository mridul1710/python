# %% [markdown]
# # PHYS 381 ASSIGNMENT 2

# %% [markdown]
# ### Simulating a pendelum without linear approximation (sin θ != θ)

# %% [markdown]
# ## Imports

# %%
import matplotlib.pylab as plt
# used to express figure axes as multiples of some constant (pi in this case)
import matplotlib.ticker as ticker
import numpy as np
import math

# %% [markdown]
# ## Global Variables

# %%
# acceleration due to gravity
g = 1
# pendelum length
L = 1
# angular frequency
phi = 2.0 / 3.0
# amplitude
A = 0.0
# damping coefficient
k = 0.0

# %% [markdown]
# ## Defining f

# %%
def f_lin(theta, omega, t):
    return  -(g / L) * theta - k * omega + A * math.cos(phi * t)

def f_nonlin(theta, omega, t):
    return  -(g / L) * math.sin(theta) - k * omega + A * math.cos(phi * t)

# %% [markdown]
# ### Set up a function to simplify multiple simulations

# %%
def simulate_and_plot(f, theta_init, omega_init, title, save=False, show=True, filename='untitled'):

    #init values
    theta = theta_init
    omega = omega_init
    t = 0.0
    dt = 0.01

    # stores our output (time, theta, omega)
    data_log = []

    # iterate 1000 times
    for i in range(1000):
        k1a = dt * omega
        k1b = dt * f(theta, omega, t)
        k2a = dt * (omega + k1b)
        k2b = dt * f(theta + k1a, omega + k1b, t + dt)
        theta = theta + (k1a + k2a) / 2
        omega = omega + (k1b + k2b ) / 2
        t = t + dt
        
        data_log.append( (t, theta, omega) )

    # retrieve values from data_log
    t_values     = [elem[0] for elem in data_log]
    theta_values = [elem[1] / math.pi for elem in data_log]
    omega_values = [elem[2] / math.pi for elem in data_log]

    # setting up the figure 
    fig = plt.figure(facecolor='white')
    ax = fig.add_subplot(1, 1, 1)
    
    # placing axes
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    # plot the function
    plt.plot(t_values, theta_values, 'r', label=r'$\theta$ (radians)')
    plt.plot(t_values, omega_values, 'b', label=r'$\omega (\frac{radians}{s})$')
    
    # express yaxis as multiples of pi
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%g $\pi$'))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(base=1.0))

    # should go from -pi to pi
    plt.ylim([-1, 1])

    # title graph
    plt.title(  title +
                 '\n'
                r'$\theta_0 = $' + f'{theta_init} | ' + r'$\omega_0 = $' + f'{omega_init}')

    # label x as time
    plt.xlabel("t (s)")

    # show legend, and show plot
    plt.legend(loc='upper right')
    
    if save: plt.savefig(f'./SavedPlots/{filename}')
    if show: plt.show()

# %% [markdown]
# ## Run through the set of initial conditions

# %%
# syntax: (theta, omega, should_save, should_show, filename)
initial_conditions = [ 
                      (1.0, 0.0, False, True, ''), 
                      (3.1, 0.0, True, True, 'Exercise_5_Part_f'), 
                      (0.0, 1.0, False, True, '') 
                      ]

for theta, omega, should_save, should_show, filename in initial_conditions:
    simulate_and_plot(f_lin, theta, omega, 'Linear solution for Non-Damped Pendelum', should_save, should_show, '')
    simulate_and_plot(f_nonlin, theta, omega, 'Non-Linear solution for Non-Damped Pendelum', should_save, should_show, filename)
